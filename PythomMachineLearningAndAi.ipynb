# %%
print("Hello World")
# Out:
# Hello World

# %%
print(10)
# Out:
# 10

# %%
print(2+2)
# Out:
# 4

# %%
print("2+2")
# Out:
# 2+2

# %%
x= "Hello World"
print(x)
print(type(x))
# Out:
# Hello World
# <class 'str'>

# %%
a=10
print(a)
# Out:
# 10

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
stringg = "Hello world"
print(type(stringg))
# Out:
# <class 'str'>

# %%
a=1
if a>2:
 print("The value of a is > 2")
elif a<2:
 print("The value of a is < 2")
else:
 print("this is 2")
# Out:
# The value of a is < 2

# %%
students = ["Habibu", "Florence", "Jean claude", "claudine"]

for name in students:
    if name == "Florence":
        break
    if name == "Jean claude":
        continue
    print(name)
# Out:
# Habibu
# Habibu
# Florence

# %%
students = ["Habibu", "Florence", "Jean claude", "claudine"]

for name in students:
    print(name)
# Out:
# Habibu
# Florence
# Jean claude
# claudine

# %%
# import numpy         //used when dealing with the number

# %%
import numpy as np
a= np.array([1,3,5,7,9]);
print(a);
print("a=\n", a)
# Out:
# [1 3 5 7 9]
# a=
#  [1 3 5 7 9]

# %%
import pandas as pd 
x = pd.Series([2,4,6,8,10]);
print(x)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
import pandas as pd
vector1 = {'X':[1,2,3],'Y':[4,5,6],'Z':[7,8,9]}
df = pd.DataFrame(data=vector1)
print(vector1)
# Out:
# {'X': [1, 2, 3], 'Y': [4, 5, 6], 'Z': [7, 8, 9]}

# %%
students = {"name": "claudine", "age": 21, "Department": "CS"}

print(students["name"])
print(students["age"])
print(students["Department"])
# Out:
# claudine
# 21
# CS

# %%
print(students.keys())
# Out:
# dict_keys(['name', 'age', 'Department'])

# %%
print(students.values())
# Out:
# dict_values(['claudine', 21, 'CS'])

# %%
import matplotlib.pyplot as plt
x=np.random.normal(size=50)
y=np.random.normal(size=50)
plt.scatter(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# plt.legend()
plt.title("This is my scatter plot")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8844\1398482054.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
x = np.array([2,3,4,5,6,7,8,9,10])
y = np.array([4,6,8,10,12,14,16,18,20])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=np.random.normal(size=500)
y=np.random.normal(size=500)
plt.scatter(x,y,color="red",edgecolor ='black')
